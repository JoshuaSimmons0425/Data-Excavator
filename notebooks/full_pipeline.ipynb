# %%
from ipynb.fs.full.eda_prototype import summary_stats
# Out:
# ---------------------------------------------------------------------------
#
# ImportError                               Traceback (most recent call last)
#
# Cell In[13], line 1
#
# ----> 1 from ipynb.fs.full.eda_prototype import summary_stats
#
#
#
# File ~\anaconda2\Lib\site-packages\ipynb\fs\full\__init__.py:39, in FullLoader.get_code(self, fullname)
#
#      32             raise ImportError('Could not import {path} for {fn}: not a valid ipynb file'.format(
#
#      33                 path=self.path,
#
#      34                 fn=fullname
#
#      35             ))
#
#      36         if not validate_nb(nb):
#
#      37             # This is when it isn't the appropriate
#
#      38             # nbformet version or language
#
# ---> 39             raise ImportError('Could not import {path} for {fn}: incorrect version or language'.format(
#
#      40                 path=self.path,
#
#      41                 fn=fullname
#
#      42             ))
#
# ...
